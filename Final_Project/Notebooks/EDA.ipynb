# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import librosa 
import librosa.display

# %% [markdown]
# ## load in csv spectrogram files

# %%
#create pandas df from csv files 
s_nan = pd.read_csv('spectrograms_nan.csv') #df with missing values 
sdf = pd.read_csv('spectrograms.csv') #df with no missing values
s_nan.head()
# Out:
#    Unnamed: 0      gbifID   type      format  \
# 0           0  1572324720  Sound  audio/mpeg
# 1           1  1572324719  Sound  audio/mpeg
# 2           2  1572324718  Sound  audio/mpeg
# 3           3  1572324717  Sound  audio/mpeg
# 4           4  1572324716  Sound  audio/mpeg
#
#                                                  URL  \
# 0  http://www.tierstimmenarchiv.de/recordings/Cre...
# 1  http://www.tierstimmenarchiv.de/recordings/Cre...
# 2  http://www.tierstimmenarchiv.de/recordings/Cre...
# 3  http://www.tierstimmenarchiv.de/recordings/Cre...
# 4  http://www.tierstimmenarchiv.de/recordings/Cre...
#
#                                           references  \
# 0  http://www.tierstimmenarchiv.de/webinterface/c...
# 1  http://www.tierstimmenarchiv.de/webinterface/c...
# 2  http://www.tierstimmenarchiv.de/webinterface/c...
# 3  http://www.tierstimmenarchiv.de/webinterface/c...
# 4  http://www.tierstimmenarchiv.de/webinterface/c...
#
#                                              license group Common Name  \
# 0  http://creativecommons.org/licenses/by-nc-sa/4.0/  Aves  Corn Crake
# 1  http://creativecommons.org/licenses/by-nc-sa/4.0/  Aves  Corn Crake
# 2  http://creativecommons.org/licenses/by-nc-sa/4.0/  Aves  Corn Crake
# 3  http://creativecommons.org/licenses/by-nc-sa/4.0/  Aves  Corn Crake
# 4  http://creativecommons.org/licenses/by-nc-sa/4.0/  Aves  Corn Crake
#
#   Scientific Name           Type            id  \
# 0       Crex crex  Not Dangerous  1.572325e+09
# 1       Crex crex  Not Dangerous  1.572325e+09
# 2       Crex crex  Not Dangerous  1.572325e+09
# 3       Crex crex  Not Dangerous  1.572325e+09
# 4       Crex crex  Not Dangerous  1.572325e+09
#
#                                                    y       sr  \
# 0  [ 0.          0.          0.         ... -0.00...  22050.0
# 1  [ 0.          0.          0.         ... -0.00...  22050.0
# 2  [ 0.          0.          0.         ... -0.03...  22050.0
# 3  [ 0.          0.          0.         ... -0.00...  22050.0
# 4  [ 0.          0.          0.         ...  0.02...  22050.0
#
#                                           melspectro  \
# 0  [[2.0839334e-04 9.2479233e-03 3.7993155e-02 .....
# 1  [[8.72581097e-07 1.43732483e-04 3.59106530e-03...
# 2  [[1.29440195e-05 6.72759349e-03 5.11190444e-02...
# 3  [[2.8849288e-06 2.5571426e-03 1.6399221e-02 .....
# 4  [[6.1422383e-05 6.1354307e-03 6.4698793e-02 .....
#
#                                        melspectro_db  \
# 0  [[-58.00468  -41.533077 -35.396465 ... -10.800...
# 1  [[-80.       -62.721558 -48.744877 ... -23.981...
# 2  [[-65.49129  -38.33338  -29.52615  ... -14.789...
# 3  [[-75.18198  -45.705772 -37.635094 ... -21.765...
# 4  [[-60.861855 -40.86667  -30.63616  ... -14.957...
#
#                                          chroma_stft  \
# 0  [[0.33644855 0.45987204 0.49630252 ... 0.32096...
# 1  [[0.37955865 0.23792116 0.26508343 ... 1.     ...
# 2  [[0.60654145 0.6226416  0.8243289  ... 0.74822...
# 3  [[0.8089813  0.81026065 0.9336924  ... 0.76193...
# 4  [[0.945572   0.72711    0.6229705  ... 0.56006...
#
#                                                  Xdb
# 0  [[-27.114927  -19.522707  -11.617491  ...  17....
# 1  [[-44.178226  -29.47525   -23.275486  ...   8....
# 2  [[-37.32677   -29.742996  -11.079779  ...  -8....
# 3  [[-40.872856  -11.780343   -6.367126  ...   3....
# 4  [[-31.734558  -24.564798  -22.052708  ...   5....

# %% [markdown]
# ## Start of EDA

# %%
s_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12375 entries, 0 to 12374
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12375 non-null  int64
#  1   gbifID           12375 non-null  int64
#  2   type             12375 non-null  object
#  3   format           12375 non-null  object
#  4   URL              12375 non-null  object
#  5   references       12375 non-null  object
#  6   license          12374 non-null  object
#  7   group            12375 non-null  object
#  8   Common Name      12375 non-null  object
#  9   Scientific Name  12375 non-null  object
#  10  Type             12375 non-null  object
#  11  id               12263 non-null  float64
#  12  y                12263 non-null  object
#  13  sr               12263 non-null  float64
#  14  melspectro       12263 non-null  object
#  15  melspectro_db    12263 non-null  object
#  16  chroma_stft      12263 non-null  object
#  17  Xdb              12263 non-null  object
# dtypes: float64(2), int64(2), object(14)
# memory usage: 1.7+ MB

# %% [markdown]
# Out of 12375 animal sounds, 12263 were able to be downloaded and transformed into spectrograms. The output below shows the missing values.

# %%
s_nan.isnull().sum()
# Out:
# Unnamed: 0           0
# gbifID               0
# type                 0
# format               0
# URL                  0
# references           0
# license              1
# group                0
# Common Name          0
# Scientific Name      0
# Type                 0
# id                 112
# y                  112
# sr                 112
# melspectro         112
# melspectro_db      112
# chroma_stft        112
# Xdb                112
# dtype: int64

# %%
s_nan.nunique()
# Out:
# Unnamed: 0         12375
# gbifID             12375
# type                   1
# format                 1
# URL                12375
# references         12375
# license                2
# group                  2
# Common Name         1388
# Scientific Name     1427
# Type                   2
# id                 12263
# y                  10934
# sr                     1
# melspectro         12258
# melspectro_db      12254
# chroma_stft        12258
# Xdb                12261
# dtype: int64

# %%
s_nan['group'].value_counts()
# Out:
# Aves         11301
# Carnivora     1074
# Name: group, dtype: int64

# %%
sdf['group'].value_counts()
# Out:
# Aves         11204
# Carnivora     1058
# Name: group, dtype: int64

# %% [markdown]
# Dataset is not balanced between Aves and Carnivora class

# %%
names = sdf.groupby(['group', 'Common Name']).size().reset_index(name='counts')
#print(names)
#plt.bar(names['Common Name'], names['counts'])

# %%
display(names.sort_values(by='counts', ascending=False))
# Out:
#      group          Common Name  counts
# 248   Aves            Chaffinch     707
# 141   Aves            Blackbird     463
# 768   Aves      Ortolan Bunting     377
# 1004  Aves          Song Thrush     302
# 480   Aves            Great Tit     272
# ...    ...                  ...     ...
# 692   Aves   Masked Gnatcatcher       1
# 694   Aves       Masked Tanager       1
# 695   Aves  Masked Yellowthroat       1
# 696   Aves       Meadow Bunting       1
# 680   Aves                Maleo       1
#
# [1361 rows x 3 columns]

# %%
##add histogram, for skewed distr.
names.hist(column="counts", by="group", bins=1000)
# Out:
# array([<AxesSubplot:title={'center':'Aves'}>,
#        <AxesSubplot:title={'center':'Carnivora'}>], dtype=object)

# %%
##consider removing all values of "1" or <50 

names2 = names[names['counts'].between(20,80)]
display(names2)
names2['counts'].sum()
names2.groupby(['group']).sum()

#export list of common names and remove from master
# Out:
#           group       Common Name  counts
# 45         Aves            Athene      20
# 73         Aves    Barred Warbler      26
# 90         Aves    Black Redstart      33
# 96         Aves  Black Woodpecker      61
# 169        Aves        Bluethroat      43
# ...         ...               ...     ...
# 1312  Carnivora      Domestic Dog      79
# 1313  Carnivora     Eurasian Lynx      28
# 1327  Carnivora           Leopard      64
# 1353  Carnivora          Sun Bear      20
# 1354  Carnivora             Tiger      73
#
# [102 rows x 3 columns]
#            counts
# group
# Aves         3359
# Carnivora     640

# %%
#------seaborn countplot - but too slow.
#plt.figure(figsize=(30,15))
#ax = sns.countplot(data=sdf, x='Common Name', hue='group', orient="V")
#ax = sns.countplot(data=sdf, x='group', hue='Common Name', orient="v")
#ax.set_xticklabels(ax.get_xticklabels(),rotation=45)

# %%
#view spectrograms example
#img = librosa.display.specshow(sdf['Xdb, x_axis='time', y_axis='mel', sr=sr, fmax=8000)

# %% [markdown]
# ## Spectrogram generation and use
# The "y" column represents the audio files amplitude only, the actual time can be figured out by using the sample rate of 22050. Based on literature review, models don't handle this data well, so it must be converted to a spectrogram. The spectrogram plots Frequency (y-axis) vs Time(x-axis) and uses color to depict Amplitude of each frequency. The brighter color represents a higher signal energy. The standard spectrogram "stft" uses Fourier Transform method to convert audio waveform into an image. However, humans cannot hear all frequencies of this method, we hear frequencies on a logarithmic scale instead of a linear scale. The Mel Scale takes this into account, so this report uses the Mel Spectrogram which includes th Mel Scale instead of Frequency (y-axis) and Decibel scale instead of Amplitude (colors).

# %% [markdown]
# ## Dataset Challenges
#
# Out of 12375 animal sounds, 12263 were able to be downloaded and transformed into spectrograms. Only ~1000 of these represent the carnivora class, so the dataset is not balanced and the carnivora class is underrepresented by the dataset. Thereofore using the data in it's unbalanced state is expected to result in bias towards the aves class. Since we are unable to collect more data due to time constraints of the project, we will need to weight different methods for balancing the dataset to achieve the most trustworthy results. The following approaches will be attempted:
#
# 1. undersampling: samples will be removed from Aves to match the length of the Carnivora Class. We expect this will lend to an overfitting problem, since the dataset will be small at approximately 2000 samples
# 2. oversampling: Using imputation or copying samples and augmenting them to increase the size of the Carnivora class that is underrepresented. Realistically this could also lead to overfitting.
# 3. Using Dataset as is, but understanding the bias.
# 4. Looking at methods other than Accuracy to gauge model performance.

# %%
## Split Dataset into Aves and Carnivora
aves = sdf[sdf['group']=='Aves']
aves_grouped = aves.groupby(['Common Name']).size().reset_index(name='counts')
aves_grouped.hist()
plt.title('aves histogram')
carnivora = sdf[sdf['group']=='Carnivora']
carn_grouped = carnivora.groupby(['Common Name']).size().reset_index(name='counts')
carn_grouped.hist()
plt.title("carnivora histogram")
# Out:
# Text(0.5, 1.0, 'carnivora histogram')

# %%
print('total creatures in aves = ',aves['Common Name'].nunique())
print('total creatures in carnivora = ',carnivora['Common Name'].nunique())
# Out:
# total creatures in aves =  1274
# total creatures in carnivora =  87

# %%
aves_short = aves_grouped[aves_grouped['counts'].between(20,80)]
display(aves_short)
print('total aves with 20<x<80 sounds = ',aves_short['counts'].sum())
print('total creatures in aves_short = ',aves_short['Common Name'].nunique())
# Out:
#            Common Name  counts
# 45              Athene      20
# 73      Barred Warbler      26
# 90      Black Redstart      33
# 96    Black Woodpecker      61
# 169         Bluethroat      43
# ...                ...     ...
# 1222        Willow Tit      36
# 1229    Wood Sandpiper      24
# 1230      Wood Warbler      53
# 1232          Woodlark      49
# 1233              Wren      74
#
# [87 rows x 2 columns]
# total aves with 20<x<80 sounds =  3359
# total creatures in aves_short =  87

# %%
carn_short = carn_grouped[carn_grouped['counts'].between(20,80)]
display(carn_short)
print('total carn with 20<x<80 sounds = ',carn_short['counts'].sum())
print('total creatures in carn_short= ',carn_short['Common Name'].nunique())
# Out:
#          Common Name  counts
# 1       African Lion      70
# 2   African Wild Dog      42
# 3         Arctic Fox      48
# 4        Arctic Wolf      36
# 16        Brown Bear      24
# 24   Clouded Leopard      25
# 29        Corsac Fox      51
# 30            Cougar      30
# 31            Coyote      20
# 37      Domestic Cat      30
# 38      Domestic Dog      79
# 39     Eurasian Lynx      28
# 53           Leopard      64
# 79          Sun Bear      20
# 80             Tiger      73
# total carn with 20<x<80 sounds =  640
# total creatures in carn_short=  15

# %%
##randomly sample species list, to get a subset of aves
aves_short_sampled = aves_short.sample(16)
aves_short_sampled.groupby(['Common Name']).size().reset_index(name='counts')
# Out:
#                  Common Name  counts
# 0           Black Woodpecker       1
# 1          Common Greenshank       1
# 2                    Dunnock       1
# 3               Eurasian Jay       1
# 4          European Nightjar       1
# 5                  Fieldfare       1
# 6         Great Reed Warbler       1
# 7   Great Spotted Woodpecker       1
# 8                  Hill Myna       1
# 9               Meadow Pipit       1
# 10                   Moorhen       1
# 11              Reed Bunting       1
# 12             Sedge Warbler       1
# 13    Short-Toed Treecreeper       1
# 14                 Tawny Owl       1
# 15                  Woodlark       1

# %%
#get only the rows associated with the dataframes within the range specified (above is 20<x<80)
aves_df = aves[aves['Common Name'].isin(aves_short_sampled['Common Name'])]
carn_df = carnivora[carnivora['Common Name'].isin(carn_short['Common Name'])]
#display(carn_df)

# %%
confirm_aves = aves_df.groupby(['Common Name']).size().reset_index(name='counts')
print('total aves samples remaining = ',confirm_aves['counts'].sum())
print('total aves species remaining = ',confirm_aves['Common Name'].nunique())
# Out:
# total aves samples remaining =  687
# total aves species remaining =  16

# %% [markdown]
# ### Undersampling Method
#
# Use 'aves_df' and 'carn_df' for undersampling method. Need to recombine and then split into train/test before modeling. 80/20 maybe since low data.

# %%
#balanced data and all species have 20-80 sounds/rows each. 
print('aves sounds total = ', len(aves_df))
print('carnivora sounds total = ',len(carn_df))
# Out:
# aves sounds total =  687
# carnivora sounds total =  640

# %%
#combine dataframes
undersampled_df = pd.concat([aves_df,carn_df])
print(len(undersampled_df))
# Out:
# 1327

# %%
##can read in and specify dtype if needed
#test_df = pd.read_csv('spectrograms', dtype={'BAR': 'S10'})

# %%
def undersample_data(filename):
    ## Split Dataset into Aves and Carnivora
    sdf = pd.read_csv(filename)
    aves = sdf[sdf['group']=='Aves']
    aves_grouped = aves.groupby(['Common Name']).size().reset_index(name='counts')
    carnivora = sdf[sdf['group']=='Carnivora']
    carn_grouped = carnivora.groupby(['Common Name']).size().reset_index(name='counts')
    #reduce datasets to only species with between 20 & 80 files
    aves_short = aves_grouped[aves_grouped['counts'].between(20,80)]
    carn_short = carn_grouped[carn_grouped['counts'].between(20,80)]
    ##randomly sample species list, to get a subset of aves, so the length is closer to len(carn)
    aves_short_sampled = aves_short.sample(16)
    aves_short_sampled.groupby(['Common Name']).size().reset_index(name='counts')
    #create the final sampled aves and carn lists from original split lists 
    aves_df = aves[aves['Common Name'].isin(aves_short_sampled['Common Name'])]
    carn_df = carnivora[carnivora['Common Name'].isin(carn_short['Common Name'])]
    #combine the split lists back into one list 
    undersampled_df = pd.concat([aves_df,carn_df])
    return undersampled_df

# %%
display(undersampled_df.head())
undersampled_df.dtypes
# Out:
#      Unnamed: 0      gbifID   type      format  \
# 252         252  1269848194  Sound  audio/mpeg
# 253         253  1269848193  Sound  audio/mpeg
# 359         359  1269848085  Sound  audio/mpeg
# 360         360  1269848084  Sound  audio/mpeg
# 370         370  1249269577  Sound  audio/mpeg
#
#                                                    URL  \
# 252  http://www.tierstimmenarchiv.de/recordings/Str...
# 253  http://www.tierstimmenarchiv.de/recordings/Str...
# 359  http://www.tierstimmenarchiv.de/recordings/Acr...
# 360  http://www.tierstimmenarchiv.de/recordings/Acr...
# 370  http://www.tierstimmenarchiv.de/recordings/Tur...
#
#                                             references  \
# 252  http://www.tierstimmenarchiv.de/webinterface/c...
# 253  http://www.tierstimmenarchiv.de/webinterface/c...
# 359  http://www.tierstimmenarchiv.de/webinterface/c...
# 360  http://www.tierstimmenarchiv.de/webinterface/c...
# 370  http://www.tierstimmenarchiv.de/webinterface/c...
#
#                                                license group    Common Name  \
# 252  http://creativecommons.org/licenses/by-nc-sa/4.0/  Aves      Tawny Owl
# 253  http://creativecommons.org/licenses/by-nc-sa/4.0/  Aves      Tawny Owl
# 359  http://creativecommons.org/licenses/by-nc-sa/4.0/  Aves  Sedge Warbler
# 360  http://creativecommons.org/licenses/by-nc-sa/4.0/  Aves  Sedge Warbler
# 370     http://creativecommons.org/licenses/by-sa/4.0/  Aves      Fieldfare
#
#                 Scientific Name           Type          id  \
# 252                 Strix aluco  Not Dangerous  1269848194
# 253                 Strix aluco  Not Dangerous  1269848193
# 359  Acrocephalus schoenobaenus  Not Dangerous  1269848085
# 360  Acrocephalus schoenobaenus  Not Dangerous  1269848084
# 370              Turdus pilaris  Not Dangerous  1249269577
#
#                                                      y       sr  \
# 252  [ 0.          0.          0.         ... -0.02...  22050.0
# 253  [ 0.          0.          0.         ... -0.03...  22050.0
# 359  [ 0.          0.          0.         ... -0.01...  22050.0
# 360  [ 0.          0.          0.         ...  0.00...  22050.0
# 370  [ 0.          0.          0.         ... -0.08...  22050.0
#
#                                             melspectro  \
# 252  [[3.3719166e-06 1.0620332e-04 1.1580186e-03 .....
# 253  [[2.5681820e-05 2.3158940e-03 8.8658057e-02 .....
# 359  [[3.87559140e-08 1.74435245e-05 1.54200927e-04...
# 360  [[2.10325226e-07 3.87714099e-05 1.17288284e-04...
# 370  [[5.42978960e-08 1.12050975e-05 6.77197313e-05...
#
#                                          melspectro_db  \
# 252  [[-63.169636  -48.187027  -37.811253  ... -13....
# 253  [[-71.36454  -51.813614 -35.98362  ... -15.953...
# 359  [[-80.       -75.35162  -65.88709  ... -59.758...
# 360  [[-80.       -69.16423  -64.356804 ... -64.066...
# 370  [[-80.       -71.627525 -63.81453  ... -17.925...
#
#                                            chroma_stft  \
# 252  [[1.         0.68147105 0.59330094 ... 0.15044...
# 253  [[0.4782309  0.6299222  0.21434094 ... 0.45576...
# 359  [[0.48747468 0.39248616 0.5527047  ... 1.     ...
# 360  [[0.7924875  0.46356493 0.6547384  ... 0.50997...
# 370  [[0.72648275 0.58275396 0.9379193  ... 0.36972...
#
#                                                    Xdb
# 252  [[-46.736866 -38.67534  -47.591038 ... -26.428...
# 253  [[-42.18498   -39.019894  -35.44049   ...  -6....
# 359  [[-38.833694 -38.833694 -38.833694 ... -24.565...
# 360  [[-42.34915  -36.36699  -33.27958  ... -42.349...
# 370  [[-47.00504   -43.04459   -29.598225  ...  10....
# Unnamed: 0           int64
# gbifID               int64
# type                object
# format              object
# URL                 object
# references          object
# license             object
# group               object
# Common Name         object
# Scientific Name     object
# Type                object
# id                   int64
# y                   object
# sr                 float64
# melspectro          object
# melspectro_db       object
# chroma_stft         object
# Xdb                 object
# dtype: object

# %% [markdown]
# ## Modeling
#
# Use melspectro_db column preferrably
